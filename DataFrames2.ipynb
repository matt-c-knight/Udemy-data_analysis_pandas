# %%
import pandas as pd

# %%
df = pd.read_csv('employees.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.describe().T
# Out:
#           count          mean           std        min          25%  \
# Salary   1000.0  90662.181000  32923.693342  35013.000  62613.00000
# Bonus %  1000.0     10.207555      5.528481      1.015      5.40175
#
#                 50%         75%         max
# Salary   90428.0000  118740.250  149908.000
# Bonus %      9.8385      14.838      19.944

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'])

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 1     Thomas    Male 1996-03-31         6:53 AM   61933    4.170
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-12-27 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-12-27 11:17:00  130590   11.858
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN
# 2             False    Finance

# %%
df['Senior Management'].astype('bool')
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999     True
# Name: Senior Management, Length: 1000, dtype: bool

# %%
df['Senior Management'] = df['Senior Management'].astype('bool')

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-12-27 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-12-27 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 55.8+ KB

# %%
df['Gender'] = df['Gender'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    category
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  1000 non-null   bool
#  7   Team               957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %%
df = pd.read_csv('employees.csv', parse_dates = ['Start Date', 'Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-12-27 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-12-27 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %% [markdown]
# # Filter a Data Frame Based On A Condition

# %%
df['Gender']
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 995       NaN
# 996      Male
# 997      Male
# 998      Male
# 999      Male
# Name: Gender, Length: 1000, dtype: category
# Categories (2, object): ['Female', 'Male']

# %%
df[df.Gender == 'Male']
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-12-27 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2020-12-27 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2020-12-27 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2020-12-27 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2020-12-27 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2020-12-27 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2020-12-27 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2020-12-27 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2020-12-27 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask = df['Start Date'] < '1985-01-01'

# %%
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 10      Louise  Female 1980-08-12 2020-12-27 09:01:00   63241   15.132
# 12     Brandon    Male 1980-12-01 2020-12-27 01:08:00  112807   17.492
# 18       Diana  Female 1981-10-23 2020-12-27 10:27:00  132940   19.082
# 28       Terry    Male 1981-11-27 2020-12-27 18:30:00  124008   13.464
# 37       Linda  Female 1981-10-19 2020-12-27 20:49:00   57427    9.557
# ..         ...     ...        ...                 ...     ...      ...
# 982       Rose  Female 1982-04-06 2020-12-27 10:43:00   91411    8.639
# 983       John    Male 1982-12-23 2020-12-27 22:35:00  146907   11.738
# 985    Stephen     NaN 1983-07-10 2020-12-27 20:10:00   85668    1.909
# 986      Donna  Female 1982-11-26 2020-12-27 07:04:00   82871   17.999
# 996    Phillip    Male 1984-01-31 2020-12-27 06:30:00   42392   19.675
#
#      Senior Management             Team
# 10                True              NaN
# ...

# %%
df[df.Salary > 110_000]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-12-27 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-12-27 13:00:00  138705    9.340
# 5       Dennis    Male 1987-04-18 2020-12-27 01:35:00  115163   10.125
# 9      Frances  Female 2002-08-08 2020-12-27 06:51:00  139852    7.524
# 12     Brandon    Male 1980-12-01 2020-12-27 01:08:00  112807   17.492
# ..         ...     ...        ...                 ...     ...      ...
# 987     Gloria  Female 2014-12-08 2020-12-27 05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25 2020-12-27 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-12-27 08:35:00  112769   11.625
# 995      Henry     NaN 2014-11-23 2020-12-27 06:09:00  132483   16.655
# 999     Albert    Male 2012-05-15 2020-12-27 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
#filtering for true values using bool
df[df['Senior Management']]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-12-27 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 3        Jerry    Male 2005-03-04 2020-12-27 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-12-27 16:47:00  101004    1.389
# 6         Ruby  Female 1987-08-17 2020-12-27 16:20:00   65476   10.012
# ..         ...     ...        ...                 ...     ...      ...
# 991       Rose  Female 2002-08-25 2020-12-27 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2020-12-27 08:35:00  112769   11.625
# 993       Tina  Female 1997-05-15 2020-12-27 15:53:00   56450   19.040
# 994     George    Male 2013-06-21 2020-12-27 17:47:00   98874    4.479
# 999     Albert    Male 2012-05-15 2020-12-27 18:24:00  129949   10.169
#
#      Senior Management             Team
# 0                 True        Marketing
# ...

# %%
df[df.Team != 'Marketing']
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-12-27 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-12-27 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-12-27 16:47:00  101004    1.389
# 5       Dennis    Male 1987-04-18 2020-12-27 01:35:00  115163   10.125
# ..         ...     ...        ...                 ...     ...      ...
# 995      Henry     NaN 2014-11-23 2020-12-27 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2020-12-27 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-12-27 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-12-27 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-12-27 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 1                 True                   NaN
# ...

# %% [markdown]
# # Multiple Conditions

# %%
df[(df.Gender == 'Male') & (df.Team == 'Marketing')]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-12-27 12:42:00   97308    6.945
# 21     Matthew   Male 1995-09-05 2020-12-27 02:12:00  100612   13.645
# 26       Craig   Male 2000-02-27 2020-12-27 07:45:00   37598    7.757
# 74      Thomas   Male 1995-06-04 2020-12-27 14:24:00   62096   17.029
# 77     Charles   Male 2004-09-14 2020-12-27 20:13:00  107391    1.260
# 101      Aaron   Male 2012-02-17 2020-12-27 10:20:00   61602   11.849
# 104       John   Male 1989-12-23 2020-12-27 07:01:00   80740   19.305
# 112     Willie   Male 2003-11-27 2020-12-27 06:21:00   64363    4.023
# 119       Paul   Male 2008-06-03 2020-12-27 15:05:00   41054   12.299
# 150       Sean   Male 1996-05-04 2020-12-27 20:59:00  135490   19.934
# 187      Roger   Male 2004-11-19 2020-12-27 15:55:00   51430    6.460
# 204     Willie   Male 2006-06-06 2020-12-27 09:45:00   55281    4.935
# ...

# %%
#Or operator
df[(df.Gender == 'Male') | (df.Team == 'Marketing')]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2020-12-27 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2020-12-27 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2020-12-27 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2020-12-27 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2020-12-27 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2020-12-27 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2020-12-27 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2020-12-27 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2020-12-27 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %%
mask1 = df['First Name'] == 'Robert'
mask2 = df['Team'] == 'Client Services'
mask3 = df['Start Date'] > '2016-06-01'

df[(mask1 & mask2) | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 15     Lillian  Female 2016-06-05 2020-12-27 06:09:00   59414    1.256
# 98        Tina  Female 2016-06-16 2020-12-27 19:47:00  100705   16.961
# 387     Robert    Male 1994-10-29 2020-12-27 04:26:00  123294   19.894
# 451      Terry     NaN 2016-07-15 2020-12-27 00:29:00  140002   19.490
#
#      Senior Management             Team
# 15               False          Product
# 98                True        Marketing
# 387              False  Client Services
# 451               True        Marketing

# %% [markdown]
# # The .isin() Method

# %%
df.head(3)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-12-27 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-12-27 11:17:00  130590   11.858
#
#    Senior Management       Team
# 0               True  Marketing
# 1               True        NaN
# 2              False    Finance

# %%
#All the rows where the value in Team column is legal, sales, or product
mask1 = df['Team'] == 'Legal'
mask2 = df['Team'] == 'Sales'
mask3 = df['Team'] == 'Product'

# %%
df[mask1 | mask2 | mask3]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2020-12-27 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-12-27 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2020-12-27 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2020-12-27 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2020-12-27 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2020-12-27 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2020-12-27 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2020-12-27 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2020-12-27 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2020-12-27 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %%
mask = df['Team'].isin(['Legal', 'Sales', 'Product'])

# %%
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 5       Dennis    Male 1987-04-18 2020-12-27 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2020-12-27 16:20:00   65476   10.012
# 11       Julie  Female 1997-10-26 2020-12-27 15:19:00  102508   12.637
# 13        Gary    Male 2008-01-27 2020-12-27 23:40:00  109831    5.831
# 15     Lillian  Female 2016-06-05 2020-12-27 06:09:00   59414    1.256
# ..         ...     ...        ...                 ...     ...      ...
# 981      James    Male 1993-01-15 2020-12-27 17:19:00  148985   19.280
# 985    Stephen     NaN 1983-07-10 2020-12-27 20:10:00   85668    1.909
# 989     Justin     NaN 1991-02-10 2020-12-27 16:58:00   38344    3.794
# 997    Russell    Male 2013-05-20 2020-12-27 12:39:00   96914    1.421
# 999     Albert    Male 2012-05-15 2020-12-27 18:24:00  129949   10.169
#
#      Senior Management     Team
# 5                False    Legal
# 6                 True  Product
# ...

# %% [markdown]
# # .isnull() and .notnull() Methods

# %%
mask = df['Team'].isnull()

# %%
df[mask]
# Out:
#       First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1         Thomas    Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 10        Louise  Female 1980-08-12 2020-12-27 09:01:00   63241   15.132
# 23           NaN    Male 2012-06-14 2020-12-27 16:19:00  125792    5.042
# 32           NaN    Male 1998-08-21 2020-12-27 14:27:00  122340    6.417
# 91         James     NaN 2005-01-26 2020-12-27 23:00:00  128771    8.309
# 109  Christopher    Male 2000-04-22 2020-12-27 10:15:00   37919   11.449
# 139          NaN  Female 1990-10-03 2020-12-27 01:08:00  132373   10.527
# 199     Jonathan    Male 2009-07-17 2020-12-27 08:15:00  130581   16.736
# 258      Michael    Male 2002-01-24 2020-12-27 03:04:00   43586   12.659
# 290       Jeremy    Male 1988-06-14 2020-12-27 18:20:00  129460   13.657
# 314        Bobby    Male 1996-03-31 2020-12-27 17:40:00  112117    6.338
# 367       Edward    Male 1989-08-04 2020-12-27 06:06:00   66067   10.957
# ...

# %%
mask = df.Gender.notnull()

# %%
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2020-12-27 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2020-12-27 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2020-12-27 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2020-12-27 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2020-12-27 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2020-12-27 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2020-12-27 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2020-12-27 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2020-12-27 18:24:00  129949   10.169
#
#      Senior Management                  Team
# 0                 True             Marketing
# ...

# %% [markdown]
# # .bewteen() Method
# - range of values

# %%
#Two parameters, lower and upper bound
df[df.Salary.between(60000, 70000)]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 1       Thomas    Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 6         Ruby  Female 1987-08-17 2020-12-27 16:20:00   65476   10.012
# 10      Louise  Female 1980-08-12 2020-12-27 09:01:00   63241   15.132
# 20        Lois     NaN 1995-04-22 2020-12-27 19:18:00   64714    4.934
# 41   Christine     NaN 2015-06-28 2020-12-27 01:08:00   66582   11.308
# ..         ...     ...        ...                 ...     ...      ...
# 965  Catherine  Female 1989-09-25 2020-12-27 01:31:00   68164   18.393
# 970      Alice  Female 1988-09-03 2020-12-27 20:54:00   63571   15.397
# 974      Harry    Male 2011-08-30 2020-12-27 18:31:00   67656   16.455
# 978       Sean    Male 1983-01-17 2020-12-27 14:23:00   66146   11.178
# 998      Larry    Male 2013-04-20 2020-12-27 16:45:00   60500   11.985
#
#      Senior Management                  Team
# 1                 True                   NaN
# ...

# %%
mask = df['Start Date'].between ("1991-01-01", "1992-12-31")

# %%
df[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 24        John    Male 1992-07-01 2020-12-27 22:08:00   97950   13.873
# 27       Scott     NaN 1991-07-11 2020-12-27 18:58:00  122367    5.218
# 75      Bonnie  Female 1991-07-02 2020-12-27 01:27:00  104897    5.118
# 88       Donna  Female 1991-11-27 2020-12-27 13:59:00   64088    6.155
# 116        NaN    Male 1991-06-22 2020-12-27 20:58:00   76189   18.988
# 131    Rebecca  Female 1992-07-10 2020-12-27 00:23:00   94231   17.517
# 146   Patricia  Female 1992-11-25 2020-12-27 02:24:00   95322    4.150
# 148    Patrick     NaN 1991-07-14 2020-12-27 02:24:00  124488   14.837
# 156     Howard    Male 1992-04-27 2020-12-27 01:10:00  105062    1.563
# 166        NaN  Female 1991-07-09 2020-12-27 18:52:00   42341    7.014
# 170      Irene  Female 1992-01-29 2020-12-27 11:36:00  133772   19.020
# 172       Sara  Female 1991-09-23 2020-12-27 18:17:00   97058    9.402
# ...

# %%
df[df['Last Login Time'].between('8:30AM', '12:00PM')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2020-12-27 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2020-12-27 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2020-12-27 09:01:00   63241   15.132
# 18       Diana  Female 1981-10-23 2020-12-27 10:27:00  132940   19.082
# 33        Jean  Female 1993-12-18 2020-12-27 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2020-12-27 11:15:00   89443   17.940
# 977      Sarah  Female 1995-12-04 2020-12-27 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2020-12-27 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2020-12-27 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2020-12-27 08:35:00  112769   11.625
#
#      Senior Management                  Team
# 2                False               Finance
# ...

# %%
import acquire

# %% [markdown]
# # Practice using Telco Sql database from class

# %%
df = acquire.get_telco_data()

# %%
telco = df.copy()

# %%
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               7043 non-null   object
#  1   gender                    7043 non-null   object
#  2   senior_citizen            7043 non-null   int64
#  3   partner                   7043 non-null   object
#  4   dependents                7043 non-null   object
#  5   tenure                    7043 non-null   int64
#  6   phone_service             7043 non-null   object
#  7   multiple_lines            7043 non-null   object
#  8   internet_service_type_id  7043 non-null   int64
#  9   online_security           7043 non-null   object
#  10  online_backup             7043 non-null   object
#  11  device_protection         7043 non-null   object
#  12  tech_support              7043 non-null   object
# ...

# %%
telco.shape
# Out:
# (7043, 24)

# %%
mask = telco['gender'] == 'Male'

# %%
telco[mask]
# Out:
#      customer_id gender  senior_citizen partner dependents  tenure  \
# 0     0003-MKNFE   Male               0      No         No       9
# 3     0023-HGHWL   Male               1      No         No       1
# 5     0067-DKWBL   Male               1      No         No       2
# 6     0076-LVEPS   Male               0      No        Yes      29
# 7     0082-LDZUE   Male               0      No         No       1
# ...          ...    ...             ...     ...        ...     ...
# 7034  9838-BFCQT   Male               0     Yes        Yes      72
# 7035  9916-AYHTC   Male               0      No         No      48
# 7038  9950-MTGYX   Male               0     Yes        Yes      28
# 7039  9953-ZMKSM   Male               0      No         No      63
# 7042  9975-GPKZU   Male               0     Yes        Yes      46
#
#      phone_service    multiple_lines  internet_service_type_id  \
# 0              Yes               Yes                         1
# ...

# %%
telco.gender.value_counts()
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
telco[telco.gender.isnull()]
# Out:
# Empty DataFrame
# Columns: [customer_id, gender, senior_citizen, partner, dependents, tenure, phone_service, multiple_lines, internet_service_type_id, online_security, online_backup, device_protection, tech_support, streaming_tv, streaming_movies, contract_type_id, paperless_billing, payment_type_id, monthly_charges, total_charges, churn, contract_type, internet_service_type, payment_type]
# Index: []
#
# [0 rows x 24 columns]

# %%
#from telco.info() can see there are no null values

# %%
mask1 = (telco.multiple_lines == 'Yes')
mask2 = (telco.churn == 'Yes')

# %%
telco[(telco.multiple_lines == 'Yes') & (telco.churn == 'Yes')]
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 17    0224-HJAPT    Male               0      No         No       5
# 73    0719-SYFRB  Female               0      No         No      12
# 74    0733-VUNUW    Male               0      No         No      24
# 120   1114-CENIM    Male               0      No        Yes      54
# 134   1251-KRREG    Male               0      No         No       2
# ...          ...     ...             ...     ...        ...     ...
# 6046  0203-HHYIJ    Male               0      No         No      25
# 6202  4597-ELFTS    Male               0      No         No      56
# 6465  1043-YCUTE    Male               0     Yes         No      56
# 6910  7951-QKZPL  Female               0     Yes        Yes      33
# 6951  8515-OCTJS  Female               0      No         No      25
#
#      phone_service multiple_lines  internet_service_type_id  \
# 17             Yes            Yes                         1
# ...

# %%
telco[mask1 & mask2]
# Out:
#      customer_id  gender  senior_citizen partner dependents  tenure  \
# 17    0224-HJAPT    Male               0      No         No       5
# 73    0719-SYFRB  Female               0      No         No      12
# 74    0733-VUNUW    Male               0      No         No      24
# 120   1114-CENIM    Male               0      No        Yes      54
# 134   1251-KRREG    Male               0      No         No       2
# ...          ...     ...             ...     ...        ...     ...
# 6046  0203-HHYIJ    Male               0      No         No      25
# 6202  4597-ELFTS    Male               0      No         No      56
# 6465  1043-YCUTE    Male               0     Yes         No      56
# 6910  7951-QKZPL  Female               0     Yes        Yes      33
# 6951  8515-OCTJS  Female               0      No         No      25
#
#      phone_service multiple_lines  internet_service_type_id  \
# 17             Yes            Yes                         1
# ...

# %% [markdown]
# # Back to working with employee data. Telco df saved for later use.

# %%
df = pd.read_csv('employees.csv', parse_dates = ['Start Date', 'Last Login Time'])
# df['Start Date'] = pd.to_datetime(df['Start Date'])
# df['Last Login Time'] = pd.to_datetime(df['Last Login Time'])
df['Senior Management'] = df['Senior Management'].astype('bool')
df['Gender'] = df['Gender'].astype('category')

# %%
df.head()
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2020-12-27 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2020-12-27 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2020-12-27 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2020-12-27 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2020-12-27 16:47:00  101004    1.389
#
#    Senior Management             Team
# 0               True        Marketing
# 1               True              NaN
# 2              False          Finance
# 3               True          Finance
# 4               True  Client Services

# %% [markdown]
# # The .duplicated() Method

# %%
df.sort_values("First Name", inplace=True)

# %%
df.head()
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron   Male 2012-02-17 2020-12-27 10:20:00   61602   11.849
# 327      Aaron   Male 1994-01-29 2020-12-27 18:48:00   58755    5.097
# 440      Aaron   Male 1990-07-22 2020-12-27 14:53:00   52119   11.343
# 937      Aaron    NaN 1986-01-22 2020-12-27 19:39:00   63126   18.424
# 137       Adam   Male 2011-05-21 2020-12-27 01:45:00   95327   15.120
#
#      Senior Management             Team
# 101               True        Marketing
# 327               True        Marketing
# 440               True  Client Services
# 937              False  Client Services
# 137              False     Distribution

# %%
#First occurance isn't a duplicate
#Keep parameter is default, can also use last
#Keep false will provide a df with all duplicates
df[df['First Name'].duplicated(keep='first')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 327      Aaron    Male 1994-01-29 2020-12-27 18:48:00   58755    5.097
# 440      Aaron    Male 1990-07-22 2020-12-27 14:53:00   52119   11.343
# 937      Aaron     NaN 1986-01-22 2020-12-27 19:39:00   63126   18.424
# 141       Adam    Male 1990-12-24 2020-12-27 20:57:00  110194   14.727
# 302       Adam    Male 2007-07-05 2020-12-27 11:59:00   71276    5.027
# ..         ...     ...        ...                 ...     ...      ...
# 902        NaN    Male 2001-05-23 2020-12-27 19:52:00  103877    6.322
# 925        NaN  Female 2000-08-23 2020-12-27 16:19:00   95866   19.388
# 946        NaN  Female 1985-09-15 2020-12-27 01:50:00  133472   16.941
# 947        NaN    Male 2012-07-30 2020-12-27 15:07:00  107351    5.329
# 951        NaN  Female 2010-09-14 2020-12-27 05:19:00  143638    9.662
#
#      Senior Management             Team
# 327               True        Marketing
# ...

# %%
#Negate it in order to only get all uniques
df[~df['First Name'].duplicated(keep='first')]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-12-27 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2020-12-27 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2020-12-27 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2020-12-27 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2020-12-27 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2020-12-27 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2020-12-27 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2020-12-27 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2020-12-27 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2020-12-27 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# ...

# %% [markdown]
# # The .drop_duplicates() Method

# %%
len(df)
# Out:
# 1000

# %%
#Only going to drop a row if all values in a row are identical to another row
len(df.drop_duplicates())
# Out:
# 1000

# %%
#Keeping first occurance of first name, dropping the others
df.drop_duplicates(subset = ['First Name'], keep='first')
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 101      Aaron    Male 2012-02-17 2020-12-27 10:20:00   61602   11.849
# 137       Adam    Male 2011-05-21 2020-12-27 01:45:00   95327   15.120
# 300       Alan    Male 1988-06-26 2020-12-27 03:54:00  111786    3.592
# 372     Albert    Male 1997-02-01 2020-12-27 16:20:00   67827   19.717
# 988      Alice  Female 2004-10-05 2020-12-27 09:34:00   47638   11.209
# ..         ...     ...        ...                 ...     ...      ...
# 433      Wanda  Female 2008-07-20 2020-12-27 13:44:00   65362    7.132
# 177      Wayne    Male 2012-04-07 2020-12-27 08:00:00  102652   14.085
# 820    William    Male 1993-11-18 2020-12-27 12:27:00   54058    5.182
# 450     Willie    Male 2009-08-22 2020-12-27 13:03:00   55038   19.691
# 7          NaN  Female 2015-07-20 2020-12-27 10:43:00   45906   11.598
#
#      Senior Management             Team
# 101               True        Marketing
# ...
